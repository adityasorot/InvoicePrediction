# %% [markdown]
# # Machine Learning Prediction

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import IsolationForest
from sklearn.covariance import EllipticEnvelope
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.datasets import load_boston
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import preprocessing

# %%
data = pd.read_csv('1830151.csv') #loading data
data.shape
# Out:
# (50000, 19)

# %% [markdown]
# General info about data

# %%
data.describe()
# Out:
#        buisness_year        doc_id  document_create_date  \
# count   50000.000000  5.000000e+04          5.000000e+04
# mean     2019.200080  2.010718e+09          2.019247e+07
# std         0.400064  2.827267e+08          3.873712e+03
# min      2019.000000  1.928500e+09          2.018123e+07
# 25%      2019.000000  1.929234e+09          2.019042e+07
# 50%      2019.000000  1.929807e+09          2.019080e+07
# 75%      2019.000000  1.930396e+09          2.019112e+07
# max      2020.000000  9.500000e+09          2.020052e+07
#
#        document_create_date.1   due_in_date  posting_id  area_business  \
# count            5.000000e+04  5.000000e+04     50000.0            0.0
# mean             2.019250e+07  2.019265e+07         1.0            NaN
# std              3.862553e+03  3.879063e+03         0.0            NaN
# min              2.018113e+07  2.018121e+07         1.0            NaN
# 25%              2.019042e+07  2.019051e+07         1.0            NaN
# 50%              2.019081e+07  2.019082e+07         1.0            NaN
# 75%              2.019112e+07  2.019121e+07         1.0            NaN
# max              2.020052e+07  2.020070e+07         1.0            NaN
#
#        total_open_amount  baseline_create_date    invoice_id        isOpen
# count       50000.000000          5.000000e+04  4.999600e+04  50000.000000
# mean        32411.668192          2.019250e+07  2.010119e+09      0.080820
# std         39973.567563          3.862947e+03  2.746868e+08      0.272561
# min             0.270000          2.018113e+07  1.928500e+09      0.000000
# 25%          4719.135000          2.019042e+07  1.929234e+09      0.000000
# 50%         17362.555000          2.019081e+07  1.929807e+09      0.000000
# 75%         46845.565000          2.019112e+07  1.930395e+09      0.000000
# max        792766.350000          2.020052e+07  2.960636e+09      1.000000

# %%
data
# Out:
#       business_code cust_number       name_customer           clear_date  \
# 0              U001  0200780383               MEIJ   2019-07-10 00:00:00
# 1              U001  0200769623  WAL-MAR foundation  2019-01-09 00:00:00
# 2              U001  0200769623  WAL-MAR associates  2019-07-26 00:00:00
# 3              U001  0200769623     WAL-MAR systems  2019-12-09 00:00:00
# 4              U001  0200936373             SUPE us  2019-06-27 00:00:00
# ...             ...         ...                 ...                  ...
# 49995          U001  0200726979          BJ'S  corp                  NaN
# 49996          U001  0200769623          WAL-MAR co                  NaN
# 49997          U001  0200769623        WAL-MAR corp                  NaN
# 49998          U001   200799367            MCL corp                  NaN
# 49999          U001  0200795490         HY -  trust                  NaN
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 0             2019.0  1.929535e+09   2019-06-24              20190624
# 1             2019.0  1.928539e+09   2018-12-30              20181229
# 2             2019.0  1.929624e+09   2019-07-16              20190716
# 3             2019.0  1.930184e+09   2019-11-22              20191122
# 4             2019.0  1.929478e+09   2019-06-11              20190612
# ...              ...           ...          ...                   ...
# 49995         2020.0  1.930855e+09   2020-05-04              20200503
# 49996         2020.0  1.930584e+09   2020-03-01              20200229
# 49997         2020.0  1.930764e+09   2020-04-10              20200408
# 49998         2020.0  1.930824e+09   2020-04-24              20200424
# 49999         2020.0  1.930693e+09   2020-03-24              20200324
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 0                    20190624   20190709.0              USD            RV
# 1                    20181230   20190114.0              USD            RV
# 2                    20190716   20190731.0              USD            RV
# 3                    20191122   20191207.0              USD            RV
# 4                    20190611   20190626.0              USD            RV
# ...                       ...          ...              ...           ...
# 49995                20200504   20200519.0              USD            RV
# 49996                20200301   20200316.0              USD            RV
# 49997                20200410   20200425.0              USD            RV
# 49998                20200424   20200215.0              USD            RV
# 49999                20200324   20200408.0              USD            RV
#
#        posting_id  area_business  total_open_amount  baseline_create_date  \
# 0             1.0            NaN           52499.91            20190624.0
# 1             1.0            NaN           34233.17            20181230.0
# 2             1.0            NaN           55955.58            20190716.0
# 3             1.0            NaN            6142.90            20191122.0
# 4             1.0            NaN           32792.21            20190611.0
# ...           ...            ...                ...                   ...
# 49995         1.0            NaN             142.89            20200504.0
# 49996         1.0            NaN           19732.43            20200301.0
# 49997         1.0            NaN           62295.39            20200410.0
# 49998         1.0            NaN           26738.53            20200131.0
# 49999         1.0            NaN           13256.43            20200324.0
#
#       cust_payment_terms    invoice_id  isOpen
# 0                   NAA8  1.929535e+09       0
# 1                   NAH4  1.928539e+09       0
# 2                   NAH4  1.929624e+09       0
# 3                   NAH4  1.930184e+09       0
# 4                   NAA8  1.929478e+09       0
# ...                  ...           ...     ...
# 49995               NAA8  1.930855e+09       1
# 49996               NAH4  1.930584e+09       1
# 49997               NAH4  1.930764e+09       1
# 49998               NAA8  1.930824e+09       1
# 49999               NAA8  1.930693e+09       1
#
# [50000 rows x 19 columns]

# %%
data.dtypes
# Out:
# business_code              object
# cust_number                object
# name_customer              object
# clear_date                 object
# buisness_year             float64
# doc_id                    float64
# posting_date               object
# document_create_date        int64
# document_create_date.1      int64
# due_in_date               float64
# invoice_currency           object
# document type              object
# posting_id                float64
# area_business             float64
# total_open_amount         float64
# baseline_create_date      float64
# cust_payment_terms         object
# invoice_id                float64
# isOpen                      int64
# dtype: object

# %%
df=data.copy()

# %%
df.head()
# Out:
#   business_code cust_number       name_customer           clear_date  \
# 0          U001  0200780383               MEIJ   2019-07-10 00:00:00
# 1          U001  0200769623  WAL-MAR foundation  2019-01-09 00:00:00
# 2          U001  0200769623  WAL-MAR associates  2019-07-26 00:00:00
# 3          U001  0200769623     WAL-MAR systems  2019-12-09 00:00:00
# 4          U001  0200936373             SUPE us  2019-06-27 00:00:00
#
#    buisness_year        doc_id posting_date  document_create_date  \
# 0         2019.0  1.929535e+09   2019-06-24              20190624
# 1         2019.0  1.928539e+09   2018-12-30              20181229
# 2         2019.0  1.929624e+09   2019-07-16              20190716
# 3         2019.0  1.930184e+09   2019-11-22              20191122
# 4         2019.0  1.929478e+09   2019-06-11              20190612
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20190624   20190709.0              USD            RV
# 1                20181230   20190114.0              USD            RV
# 2                20190716   20190731.0              USD            RV
# 3                20191122   20191207.0              USD            RV
# 4                20190611   20190626.0              USD            RV
#
#    posting_id  area_business  total_open_amount  baseline_create_date  \
# 0         1.0            NaN           52499.91            20190624.0
# 1         1.0            NaN           34233.17            20181230.0
# 2         1.0            NaN           55955.58            20190716.0
# 3         1.0            NaN            6142.90            20191122.0
# 4         1.0            NaN           32792.21            20190611.0
#
#   cust_payment_terms    invoice_id  isOpen
# 0               NAA8  1.929535e+09       0
# 1               NAH4  1.928539e+09       0
# 2               NAH4  1.929624e+09       0
# 3               NAH4  1.930184e+09       0
# 4               NAA8  1.929478e+09       0

# %% [markdown]
# Converting all dates to datetime format

# %%
def con_date_time(df):
    df['clear_date']=pd.to_datetime(df['clear_date'])
    df['posting_date']=pd.to_datetime(df['posting_date'])
    df['due_in_date']=pd.to_datetime(df['due_in_date'],format='%Y%m%d', errors='ignore')
    df['document_create_date']=pd.to_datetime(df['document_create_date'],format='%Y%m%d', errors='ignore')
    df['document_create_date.1']=pd.to_datetime(df['document_create_date.1'],format='%Y%m%d', errors='ignore')
    df['baseline_create_date']=pd.to_datetime(df['baseline_create_date'], format='%Y%m%d', errors='ignore')
    df['buisness_year']=df['buisness_year'].astype(int)
    return None

# %%
con_date_time(df)

# %%
df.head(1)
# Out:
#   business_code cust_number name_customer clear_date  buisness_year  \
# 0          U001  0200780383         MEIJ  2019-07-10           2019
#
#          doc_id posting_date document_create_date document_create_date.1  \
# 0  1.929535e+09   2019-06-24           2019-06-24             2019-06-24
#
#   due_in_date invoice_currency document type  posting_id  area_business  \
# 0  2019-07-09              USD            RV         1.0            NaN
#
#    total_open_amount baseline_create_date cust_payment_terms    invoice_id  \
# 0           52499.91           2019-06-24               NAA8  1.929535e+09
#
#    isOpen
# 0       0

# %%
df.dtypes
# Out:
# business_code                     object
# cust_number                       object
# name_customer                     object
# clear_date                datetime64[ns]
# buisness_year                      int64
# doc_id                           float64
# posting_date              datetime64[ns]
# document_create_date      datetime64[ns]
# document_create_date.1    datetime64[ns]
# due_in_date               datetime64[ns]
# invoice_currency                  object
# document type                     object
# posting_id                       float64
# area_business                    float64
# total_open_amount                float64
# baseline_create_date      datetime64[ns]
# cust_payment_terms                object
# invoice_id                       float64
# isOpen                             int64
# dtype: object

# %% [markdown]
# Dropping Extra document create date column and sorting for distribution

# %%
df.drop(['document_create_date'],axis=1,inplace=True)
df=df.sort_values(by='document_create_date.1',ignore_index=True)
df=df.rename(columns={'document_create_date.1':'document_create_date'})

# %%
data_train=df.loc[data['clear_date'].notna()]
data_train=data_train.reset_index(drop=True)
data_null_cleardate=df.loc[data['clear_date'].isna()]
data_null_cleardate=data_null_cleardate.reset_index(drop=True)

# %% [markdown]
# Removing anomalies in the data

# %%
df=data_train.copy()
df=(df.loc[df['document_create_date']<=df['posting_date']].loc[df['posting_date']<=df['due_in_date']].loc[df['baseline_create_date']<=df['due_in_date']].loc[df['baseline_create_date']<=df['clear_date']])

# %%
df['due_duration']=(df['clear_date']-df['due_in_date']).dt.days
df=df.drop(['clear_date'],axis=1)

# %% [markdown]
# ### Initital EDA

# %%
drop = [] # list of columns to be dropped

# %%
for i in df.columns:
    if bool(list(df[i].isna().value_counts().index)[0]):
        print(i)
# Out:
# area_business

# %%
drop.append("area_business")

# %%
for i in df.columns:
    print(i)
    print(df[i].nunique())
    if df[i].nunique()<100:
        print()
        print(df[i].value_counts())
    print()
# Out:
# business_code
# 6
#
# U001    41441
# CA02     3565
# U013      674
# U002      127
# U005       10
# U007        2
# Name: business_code, dtype: int64
#
# cust_number
# 1408
#
# name_customer
# 4235
#
# buisness_year
# 2
#
# 2019    39875
# 2020     5944
# Name: buisness_year, dtype: int64
#
# doc_id
# 45819
#
# posting_date
# 420
#
# document_create_date
# 420
#
# due_in_date
# 493
#
# invoice_currency
# 2
#
# USD    42253
# CAD     3566
# Name: invoice_currency, dtype: int64
#
# document type
# 1
#
# RV    45819
# Name: document type, dtype: int64
#
# posting_id
# 1
#
# 1.0    45819
# Name: posting_id, dtype: int64
#
# area_business
# 0
#
# Series([], Name: area_business, dtype: int64)
#
# total_open_amount
# 41475
#
# baseline_create_date
# 430
#
# cust_payment_terms
# 72
#
# NAA8    18388
# NAH4    12008
# CA10     3483
# NAC6     1571
# NAM4     1291
#         ...
# NATW        1
# NAUN        1
# NATM        1
# NABD        1
# B112        1
# Name: cust_payment_terms, Length: 72, dtype: int64
#
# invoice_id
# 45819
#
# isOpen
# 1
#
# 0    45819
# Name: isOpen, dtype: int64
#
# due_duration
# 179

# %%
df.dtypes
# Out:
# business_code                   object
# cust_number                     object
# name_customer                   object
# buisness_year                    int64
# doc_id                         float64
# posting_date            datetime64[ns]
# document_create_date    datetime64[ns]
# due_in_date             datetime64[ns]
# invoice_currency                object
# document type                   object
# posting_id                     float64
# area_business                  float64
# total_open_amount              float64
# baseline_create_date    datetime64[ns]
# cust_payment_terms              object
# invoice_id                     float64
# isOpen                           int64
# due_duration                     int64
# dtype: object

# %%
dfc=df.select_dtypes(include=['float64','int64']).copy()

# %% [markdown]
# ### Constant Features

# %%
sel = VarianceThreshold(threshold=0)
sel.fit(dfc) 
sum(sel.get_support())
len(dfc.columns[sel.get_support()])
print(
    len([
        x for x in dfc.columns
        if x not in dfc.columns[sel.get_support()]
    ]))

q=[x for x in dfc.columns if x not in dfc.columns[sel.get_support()]]
q
# Out:
# 3
# /home/xandier/.local/lib/python3.8/site-packages/sklearn/feature_selection/_variance_threshold.py:78: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   self.variances_ = np.nanvar(X, axis=0)
# /home/xandier/.local/lib/python3.8/site-packages/sklearn/feature_selection/_variance_threshold.py:86: RuntimeWarning: All-NaN slice encountered
#   self.variances_ = np.nanmin(compare_arr, axis=0)
# ['posting_id', 'area_business', 'isOpen']

# %%
for i in q:
    drop.append(i)

# %% [markdown]
# ### Quasi Constant

# %%
sel = VarianceThreshold(threshold=0.4)
sel.fit(dfc) 
sum(sel.get_support())
len(dfc.columns[sel.get_support()])
print(
    len([
        x for x in dfc.columns
        if x not in dfc.columns[sel.get_support()]
    ]))

q=[x for x in dfc.columns if x not in dfc.columns[sel.get_support()]]
q
# Out:
# 4
# /home/xandier/.local/lib/python3.8/site-packages/sklearn/feature_selection/_variance_threshold.py:78: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   self.variances_ = np.nanvar(X, axis=0)
# ['buisness_year', 'posting_id', 'area_business', 'isOpen']

# %%
# none right now

# %% [markdown]
# ## Splitting

# %%
x_train, x_test_init = train_test_split(
    df,
    test_size=0.3,
    shuffle=False)
x_train.shape,  x_test_init.shape
# Out:
# ((32073, 18), (13746, 18))

# %%
x_val, x_test = train_test_split(
    x_test_init,
    test_size=0.5,
    shuffle=False)

x_val.shape, x_test.shape
# Out:
# ((6873, 18), (6873, 18))

# %% [markdown]
# ### Feature Engg

# %%
df=x_train.copy()
a=df
# Encoding String terms
code_business_code = {k: i for i, k in enumerate(a.business_code.unique(), 1)}
code_cust_payment_terms = {k: i for i, k in enumerate(a.cust_payment_terms.unique(), 1)}
code_cust_number = {k: i for i, k in enumerate(a.cust_number.unique(), 1)}
code_name_customer = {k: i for i, k in enumerate(a.name_customer.unique(), 1)}

def encoding(df_obj):
    df_obj.loc[:, 'code_business_code'] = df_obj.loc[:, 'business_code'].map(code_business_code)
    df_obj.loc[:, 'code_cust_payment_terms'] = df_obj.loc[:, 'cust_payment_terms'].map(code_cust_payment_terms)
    df_obj.loc[:, 'code_cust_number'] = df_obj.loc[:, 'cust_number'].map(code_cust_number)
    df_obj.loc[:, 'code_name_customer'] = df_obj.loc[:, 'name_customer'].map(code_name_customer)
    return None

# creating fetures from date
def dates_feature(df_dates):
    df_dates['posting_date_month'],df_dates['posting_date_day'],df_dates['posting_date_year'],df_dates['posting_date_quarter'],df_dates['posting_date_dayofweek'],df_dates['posting_date_week']=df_dates['posting_date'].dt.month,df_dates['posting_date'].dt.day,df_dates['posting_date'].dt.year,df_dates['posting_date'].dt.quarter,df_dates['posting_date'].dt.dayofweek,df_dates['posting_date'].dt.isocalendar().week.astype(int)
    df_dates['due_in_date_month'],df_dates['due_in_date_day'],df_dates['due_in_date_year'],df_dates['due_in_date_quarter'],df_dates['due_in_date_dayofweek'],df_dates['due_in_date_week']=df_dates['due_in_date'].dt.month,df_dates['due_in_date'].dt.day,df_dates['due_in_date'].dt.year,df_dates['due_in_date'].dt.quarter,df_dates['due_in_date'].dt.dayofweek,df_dates['due_in_date'].dt.isocalendar().week.astype(int)
    df_dates['document_create_date_month'],df_dates['document_create_date_day'],df_dates['document_create_date_year'],df_dates['document_create_date_quarter'],df_dates['document_create_date_dayofweek'],df_dates['document_create_date_week']=df_dates['document_create_date'].dt.month,df_dates['document_create_date'].dt.day,df_dates['document_create_date'].dt.year,df_dates['document_create_date'].dt.quarter,df_dates['document_create_date'].dt.dayofweek,df_dates['document_create_date'].dt.isocalendar().week.astype(int)
    df_dates['baseline_create_date_month'],df_dates['baseline_create_date_day'],df_dates['baseline_create_date_year'],df_dates['baseline_create_date_quarter'],df_dates['baseline_create_date_dayofweek'],df_dates['baseline_create_date_week']=df_dates['baseline_create_date'].dt.month,df_dates['baseline_create_date'].dt.day,df_dates['baseline_create_date'].dt.year,df_dates['baseline_create_date'].dt.quarter,df_dates['baseline_create_date'].dt.dayofweek,df_dates['baseline_create_date'].dt.isocalendar().week.astype(int)
    return None

encoding(df)
dates_feature(df)

# %%
df['document_create_is_working']=np.where(df.document_create_date_dayofweek.isin([5,6]),0,1)
df['due_in_is_working']=np.where(df.due_in_date_dayofweek.isin([5,6]),0,1)

# %%
for i in ['posting_date','document_create_date','due_in_date','baseline_create_date','name_customer','cust_number','cust_payment_terms','business_code']:
    drop.append(i)

# %%
mapper1=df.groupby('code_cust_number')['due_duration'].mean()
mapper2=df.groupby('code_name_customer')['due_duration'].mean()

df['cust_delay_mean']=df['code_cust_number'].map(mapper1)
df['cust_name_delay_mean']=df['code_name_customer'].map(mapper2)
df['payment_time']=(df['due_in_date']-df['document_create_date']).dt.days

mappingData = [mapper1,mapper2]

# %%
import pickle
with open("mapper", 'wb') as f:
    pickle.dump(mappingData, f)

# %%
df['conv_amt']=df['total_open_amount'].copy()
df.loc[df['invoice_currency']=='CAD','conv_amt']=df.loc[df['invoice_currency']=='CAD','conv_amt']*0.78

# %%
df['cust_number'].loc[df['cust_number'].str.isdigit()!=True]
# Out:
# 18       CCU013
# 35       CCU013
# 61       CCU013
# 62       CC5050
# 114      CC7470
#           ...
# 32029    CCU013
# 32091    CCU013
# 32092    CCU013
# 32114    CCU002
# 32121    CCU013
# Name: cust_number, Length: 1122, dtype: object

# %%
sns.countplot(x='cust_payment_terms',data=df)
# Out:
# <AxesSubplot:xlabel='cust_payment_terms', ylabel='count'>

# %%
sns.countplot(x='business_code',data=df)
# Out:
# <AxesSubplot:xlabel='business_code', ylabel='count'>

# %%
sns.countplot(x='cust_number',data=df)
# Out:
# <AxesSubplot:xlabel='cust_number', ylabel='count'>

# %%
sns.countplot(x='invoice_currency',data=df)
# Out:
# <AxesSubplot:xlabel='invoice_currency', ylabel='count'>

# %%
corr=df.corr().abs()

u=corr.where(np.triu(np.ones(corr.shape), k=1).astype(np.bool))
u
# Out:
# <ipython-input-43-7c2248fed8e4>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   u=corr.where(np.triu(np.ones(corr.shape), k=1).astype(np.bool))
#                                 buisness_year  doc_id  posting_id  \
# buisness_year                             NaN     NaN         NaN
# doc_id                                    NaN     NaN         NaN
# posting_id                                NaN     NaN         NaN
# area_business                             NaN     NaN         NaN
# total_open_amount                         NaN     NaN         NaN
# invoice_id                                NaN     NaN         NaN
# isOpen                                    NaN     NaN         NaN
# due_duration                              NaN     NaN         NaN
# code_business_code                        NaN     NaN         NaN
# code_cust_payment_terms                   NaN     NaN         NaN
# code_cust_number                          NaN     NaN         NaN
# code_name_customer                        NaN     NaN         NaN
# posting_date_month                        NaN     NaN         NaN
# posting_date_day                          NaN     NaN         NaN
# posting_date_year                         NaN     NaN         NaN
# posting_date_quarter                      NaN     NaN         NaN
# posting_date_dayofweek                    NaN     NaN         NaN
# posting_date_week                         NaN     NaN         NaN
# due_in_date_month                         NaN     NaN         NaN
# due_in_date_day                           NaN     NaN         NaN
# due_in_date_year                          NaN     NaN         NaN
# due_in_date_quarter                       NaN     NaN         NaN
# due_in_date_dayofweek                     NaN     NaN         NaN
# due_in_date_week                          NaN     NaN         NaN
# document_create_date_month                NaN     NaN         NaN
# document_create_date_day                  NaN     NaN         NaN
# document_create_date_year                 NaN     NaN         NaN
# document_create_date_quarter              NaN     NaN         NaN
# document_create_date_dayofweek            NaN     NaN         NaN
# document_create_date_week                 NaN     NaN         NaN
# baseline_create_date_month                NaN     NaN         NaN
# baseline_create_date_day                  NaN     NaN         NaN
# baseline_create_date_year                 NaN     NaN         NaN
# baseline_create_date_quarter              NaN     NaN         NaN
# baseline_create_date_dayofweek            NaN     NaN         NaN
# baseline_create_date_week                 NaN     NaN         NaN
# document_create_is_working                NaN     NaN         NaN
# due_in_is_working                         NaN     NaN         NaN
# cust_delay_mean                           NaN     NaN         NaN
# cust_name_delay_mean                      NaN     NaN         NaN
# payment_time                              NaN     NaN         NaN
# conv_amt                                  NaN     NaN         NaN
#
#                                 area_business  total_open_amount  invoice_id  \
# buisness_year                             NaN                NaN         NaN
# doc_id                                    NaN           0.185018    1.000000
# posting_id                                NaN                NaN         NaN
# area_business                             NaN                NaN         NaN
# total_open_amount                         NaN                NaN    0.185018
# invoice_id                                NaN                NaN         NaN
# isOpen                                    NaN                NaN         NaN
# due_duration                              NaN                NaN         NaN
# code_business_code                        NaN                NaN         NaN
# code_cust_payment_terms                   NaN                NaN         NaN
# code_cust_number                          NaN                NaN         NaN
# code_name_customer                        NaN                NaN         NaN
# posting_date_month                        NaN                NaN         NaN
# posting_date_day                          NaN                NaN         NaN
# posting_date_year                         NaN                NaN         NaN
# posting_date_quarter                      NaN                NaN         NaN
# posting_date_dayofweek                    NaN                NaN         NaN
# posting_date_week                         NaN                NaN         NaN
# due_in_date_month                         NaN                NaN         NaN
# due_in_date_day                           NaN                NaN         NaN
# due_in_date_year                          NaN                NaN         NaN
# due_in_date_quarter                       NaN                NaN         NaN
# due_in_date_dayofweek                     NaN                NaN         NaN
# due_in_date_week                          NaN                NaN         NaN
# document_create_date_month                NaN                NaN         NaN
# document_create_date_day                  NaN                NaN         NaN
# document_create_date_year                 NaN                NaN         NaN
# document_create_date_quarter              NaN                NaN         NaN
# document_create_date_dayofweek            NaN                NaN         NaN
# document_create_date_week                 NaN                NaN         NaN
# baseline_create_date_month                NaN                NaN         NaN
# baseline_create_date_day                  NaN                NaN         NaN
# baseline_create_date_year                 NaN                NaN         NaN
# baseline_create_date_quarter              NaN                NaN         NaN
# baseline_create_date_dayofweek            NaN                NaN         NaN
# baseline_create_date_week                 NaN                NaN         NaN
# document_create_is_working                NaN                NaN         NaN
# due_in_is_working                         NaN                NaN         NaN
# cust_delay_mean                           NaN                NaN         NaN
# cust_name_delay_mean                      NaN                NaN         NaN
# payment_time                              NaN                NaN         NaN
# conv_amt                                  NaN                NaN         NaN
#
#                                 isOpen  due_duration  code_business_code  \
# buisness_year                      NaN           NaN                 NaN
# doc_id                             NaN      0.134165            0.664496
# posting_id                         NaN           NaN                 NaN
# area_business                      NaN           NaN                 NaN
# total_open_amount                  NaN      0.000319            0.104911
# invoice_id                         NaN      0.134165            0.664496
# isOpen                             NaN           NaN                 NaN
# due_duration                       NaN           NaN            0.152613
# code_business_code                 NaN           NaN                 NaN
# code_cust_payment_terms            NaN           NaN                 NaN
# code_cust_number                   NaN           NaN                 NaN
# code_name_customer                 NaN           NaN                 NaN
# posting_date_month                 NaN           NaN                 NaN
# posting_date_day                   NaN           NaN                 NaN
# posting_date_year                  NaN           NaN                 NaN
# posting_date_quarter               NaN           NaN                 NaN
# posting_date_dayofweek             NaN           NaN                 NaN
# posting_date_week                  NaN           NaN                 NaN
# due_in_date_month                  NaN           NaN                 NaN
# due_in_date_day                    NaN           NaN                 NaN
# due_in_date_year                   NaN           NaN                 NaN
# due_in_date_quarter                NaN           NaN                 NaN
# due_in_date_dayofweek              NaN           NaN                 NaN
# due_in_date_week                   NaN           NaN                 NaN
# document_create_date_month         NaN           NaN                 NaN
# document_create_date_day           NaN           NaN                 NaN
# document_create_date_year          NaN           NaN                 NaN
# document_create_date_quarter       NaN           NaN                 NaN
# document_create_date_dayofweek     NaN           NaN                 NaN
# document_create_date_week          NaN           NaN                 NaN
# baseline_create_date_month         NaN           NaN                 NaN
# baseline_create_date_day           NaN           NaN                 NaN
# baseline_create_date_year          NaN           NaN                 NaN
# baseline_create_date_quarter       NaN           NaN                 NaN
# baseline_create_date_dayofweek     NaN           NaN                 NaN
# baseline_create_date_week          NaN           NaN                 NaN
# document_create_is_working         NaN           NaN                 NaN
# due_in_is_working                  NaN           NaN                 NaN
# cust_delay_mean                    NaN           NaN                 NaN
# cust_name_delay_mean               NaN           NaN                 NaN
# payment_time                       NaN           NaN                 NaN
# conv_amt                           NaN           NaN                 NaN
#
#                                 code_cust_payment_terms  ...  \
# buisness_year                                       NaN  ...
# doc_id                                         0.102375  ...
# posting_id                                          NaN  ...
# area_business                                       NaN  ...
# total_open_amount                              0.130131  ...
# invoice_id                                     0.102375  ...
# isOpen                                              NaN  ...
# due_duration                                   0.140586  ...
# code_business_code                             0.012384  ...
# code_cust_payment_terms                             NaN  ...
# code_cust_number                                    NaN  ...
# code_name_customer                                  NaN  ...
# posting_date_month                                  NaN  ...
# posting_date_day                                    NaN  ...
# posting_date_year                                   NaN  ...
# posting_date_quarter                                NaN  ...
# posting_date_dayofweek                              NaN  ...
# posting_date_week                                   NaN  ...
# due_in_date_month                                   NaN  ...
# due_in_date_day                                     NaN  ...
# due_in_date_year                                    NaN  ...
# due_in_date_quarter                                 NaN  ...
# due_in_date_dayofweek                               NaN  ...
# due_in_date_week                                    NaN  ...
# document_create_date_month                          NaN  ...
# document_create_date_day                            NaN  ...
# document_create_date_year                           NaN  ...
# document_create_date_quarter                        NaN  ...
# document_create_date_dayofweek                      NaN  ...
# document_create_date_week                           NaN  ...
# baseline_create_date_month                          NaN  ...
# baseline_create_date_day                            NaN  ...
# baseline_create_date_year                           NaN  ...
# baseline_create_date_quarter                        NaN  ...
# baseline_create_date_dayofweek                      NaN  ...
# baseline_create_date_week                           NaN  ...
# document_create_is_working                          NaN  ...
# due_in_is_working                                   NaN  ...
# cust_delay_mean                                     NaN  ...
# cust_name_delay_mean                                NaN  ...
# payment_time                                        NaN  ...
# conv_amt                                            NaN  ...
#
#                                 baseline_create_date_year  \
# buisness_year                                         NaN
# doc_id                                           0.015028
# posting_id                                            NaN
# area_business                                         NaN
# total_open_amount                                0.003763
# invoice_id                                       0.015028
# isOpen                                                NaN
# due_duration                                     0.006417
# code_business_code                               0.006914
# code_cust_payment_terms                          0.020970
# code_cust_number                                 0.036941
# code_name_customer                               0.045409
# posting_date_month                               0.163037
# posting_date_day                                 0.106693
# posting_date_year                                0.977433
# posting_date_quarter                             0.142226
# posting_date_dayofweek                           0.001635
# posting_date_week                                0.016677
# due_in_date_month                                0.106681
# due_in_date_day                                  0.005099
# due_in_date_year                                 0.131981
# due_in_date_quarter                              0.081396
# due_in_date_dayofweek                            0.076134
# due_in_date_week                                 0.105463
# document_create_date_month                       0.163037
# document_create_date_day                         0.106693
# document_create_date_year                        0.977433
# document_create_date_quarter                     0.142226
# document_create_date_dayofweek                   0.001635
# document_create_date_week                        0.016677
# baseline_create_date_month                       0.162858
# baseline_create_date_day                         0.107350
# baseline_create_date_year                             NaN
# baseline_create_date_quarter                          NaN
# baseline_create_date_dayofweek                        NaN
# baseline_create_date_week                             NaN
# document_create_is_working                            NaN
# due_in_is_working                                     NaN
# cust_delay_mean                                       NaN
# cust_name_delay_mean                                  NaN
# payment_time                                          NaN
# conv_amt                                              NaN
#
#                                 baseline_create_date_quarter  \
# buisness_year                                            NaN
# doc_id                                              0.011937
# posting_id                                               NaN
# area_business                                            NaN
# total_open_amount                                   0.004740
# invoice_id                                          0.011937
# isOpen                                                   NaN
# due_duration                                        0.013001
# code_business_code                                  0.000873
# code_cust_payment_terms                             0.009189
# code_cust_number                                    0.030191
# code_name_customer                                  0.107695
# posting_date_month                                  0.948300
# posting_date_day                                    0.054326
# posting_date_year                                   0.134973
# posting_date_quarter                                0.996585
# posting_date_dayofweek                              0.005104
# posting_date_week                                   0.924145
# due_in_date_month                                   0.890616
# due_in_date_day                                     0.024786
# due_in_date_year                                    0.015692
# due_in_date_quarter                                 0.880249
# due_in_date_dayofweek                               0.023160
# due_in_date_week                                    0.900396
# document_create_date_month                          0.948300
# document_create_date_day                            0.054326
# document_create_date_year                           0.134973
# document_create_date_quarter                        0.996585
# document_create_date_dayofweek                      0.005104
# document_create_date_week                           0.924145
# baseline_create_date_month                          0.950390
# baseline_create_date_day                            0.058121
# baseline_create_date_year                           0.141750
# baseline_create_date_quarter                             NaN
# baseline_create_date_dayofweek                           NaN
# baseline_create_date_week                                NaN
# document_create_is_working                               NaN
# due_in_is_working                                        NaN
# cust_delay_mean                                          NaN
# cust_name_delay_mean                                     NaN
# payment_time                                             NaN
# conv_amt                                                 NaN
#
#                                 baseline_create_date_dayofweek  \
# buisness_year                                              NaN
# doc_id                                                0.001484
# posting_id                                                 NaN
# area_business                                              NaN
# total_open_amount                                     0.022845
# invoice_id                                            0.001484
# isOpen                                                     NaN
# due_duration                                          0.001147
# code_business_code                                    0.015221
# code_cust_payment_terms                               0.012719
# code_cust_number                                      0.077484
# code_name_customer                                    0.099204
# posting_date_month                                    0.005788
# posting_date_day                                      0.022624
# posting_date_year                                     0.001292
# posting_date_quarter                                  0.022032
# posting_date_dayofweek                                0.905632
# posting_date_week                                     0.002587
# due_in_date_month                                     0.006270
# due_in_date_day                                       0.001492
# due_in_date_year                                      0.013255
# due_in_date_quarter                                   0.012384
# due_in_date_dayofweek                                 0.246791
# due_in_date_week                                      0.000854
# document_create_date_month                            0.005788
# document_create_date_day                              0.022624
# document_create_date_year                             0.001292
# document_create_date_quarter                          0.022032
# document_create_date_dayofweek                        0.905632
# document_create_date_week                             0.002587
# baseline_create_date_month                            0.005618
# baseline_create_date_day                              0.018778
# baseline_create_date_year                             0.001028
# baseline_create_date_quarter                          0.023360
# baseline_create_date_dayofweek                             NaN
# baseline_create_date_week                                  NaN
# document_create_is_working                                 NaN
# due_in_is_working                                          NaN
# cust_delay_mean                                            NaN
# cust_name_delay_mean                                       NaN
# payment_time                                               NaN
# conv_amt                                                   NaN
#
#                                 baseline_create_date_week  \
# buisness_year                                         NaN
# doc_id                                           0.015067
# posting_id                                            NaN
# area_business                                         NaN
# total_open_amount                                0.003055
# invoice_id                                       0.015067
# isOpen                                                NaN
# due_duration                                     0.013254
# code_business_code                               0.004637
# code_cust_payment_terms                          0.015484
# code_cust_number                                 0.025286
# code_name_customer                               0.128114
# posting_date_month                               0.970688
# posting_date_day                                 0.047304
# posting_date_year                                0.009156
# posting_date_quarter                             0.923657
# posting_date_dayofweek                           0.007735
# posting_date_week                                0.997737
# due_in_date_month                                0.966961
# due_in_date_day                                  0.014288
# due_in_date_year                                 0.018617
# due_in_date_quarter                              0.926570
# due_in_date_dayofweek                            0.019084
# due_in_date_week                                 0.972419
# document_create_date_month                       0.970688
# document_create_date_day                         0.047304
# document_create_date_year                        0.009156
# document_create_date_quarter                     0.923657
# document_create_date_dayofweek                   0.007735
# document_create_date_week                        0.997737
# baseline_create_date_month                       0.972668
# baseline_create_date_day                         0.049456
# baseline_create_date_year                        0.014523
# baseline_create_date_quarter                     0.925494
# baseline_create_date_dayofweek                   0.000042
# baseline_create_date_week                             NaN
# document_create_is_working                            NaN
# due_in_is_working                                     NaN
# cust_delay_mean                                       NaN
# cust_name_delay_mean                                  NaN
# payment_time                                          NaN
# conv_amt                                              NaN
#
#                                 document_create_is_working  due_in_is_working  \
# buisness_year                                          NaN                NaN
# doc_id                                            0.003407           0.063419
# posting_id                                             NaN                NaN
# area_business                                          NaN                NaN
# total_open_amount                                 0.009543           0.010747
# invoice_id                                        0.003407           0.063419
# isOpen                                                 NaN                NaN
# due_duration                                      0.003548           0.004009
# code_business_code                                0.019900           0.041604
# code_cust_payment_terms                           0.045052           0.033072
# code_cust_number                                  0.103859           0.011455
# code_name_customer                                0.130558           0.010363
# posting_date_month                                0.023397           0.002088
# posting_date_day                                  0.019634           0.000428
# posting_date_year                                 0.050518           0.029729
# posting_date_quarter                              0.005330           0.011926
# posting_date_dayofweek                            0.711802           0.383384
# posting_date_week                                 0.014146           0.005092
# due_in_date_month                                 0.009320           0.010129
# due_in_date_day                                   0.003125           0.009066
# due_in_date_year                                  0.019598           0.008972
# due_in_date_quarter                               0.005746           0.009946
# due_in_date_dayofweek                             0.001726           0.775615
# due_in_date_week                                  0.009107           0.006884
# document_create_date_month                        0.023397           0.002088
# document_create_date_day                          0.019634           0.000428
# document_create_date_year                         0.050518           0.029729
# document_create_date_quarter                      0.005330           0.011926
# document_create_date_dayofweek                    0.711802           0.383384
# document_create_date_week                         0.014146           0.005092
# baseline_create_date_month                        0.022744           0.002890
# baseline_create_date_day                          0.021928           0.000636
# baseline_create_date_year                         0.046512           0.035159
# baseline_create_date_quarter                      0.005633           0.013387
# baseline_create_date_dayofweek                    0.640155           0.413317
# baseline_create_date_week                         0.014933           0.006289
# document_create_is_working                             NaN           0.195032
# due_in_is_working                                      NaN                NaN
# cust_delay_mean                                        NaN                NaN
# cust_name_delay_mean                                   NaN                NaN
# payment_time                                           NaN                NaN
# conv_amt                                               NaN                NaN
#
#                                 cust_delay_mean  cust_name_delay_mean  \
# buisness_year                               NaN                   NaN
# doc_id                                 0.193867              0.172317
# posting_id                                  NaN                   NaN
# area_business                               NaN                   NaN
# total_open_amount                      0.008375              0.010076
# invoice_id                             0.193867              0.172317
# isOpen                                      NaN                   NaN
# due_duration                           0.692572              0.740264
# code_business_code                     0.220556              0.192113
# code_cust_payment_terms                0.024674              0.041232
# code_cust_number                       0.002092              0.006246
# code_name_customer                     0.080676              0.072153
# posting_date_month                     0.008616              0.009711
# posting_date_day                       0.008621              0.007161
# posting_date_year                      0.010082              0.006927
# posting_date_quarter                   0.009861              0.010344
# posting_date_dayofweek                 0.004880              0.006895
# posting_date_week                      0.007549              0.008578
# due_in_date_month                      0.015795              0.018838
# due_in_date_day                        0.005405              0.005876
# due_in_date_year                       0.046576              0.046806
# due_in_date_quarter                    0.019054              0.021535
# due_in_date_dayofweek                  0.001526              0.002559
# due_in_date_week                       0.015414              0.018501
# document_create_date_month             0.008616              0.009711
# document_create_date_day               0.008621              0.007161
# document_create_date_year              0.010082              0.006927
# document_create_date_quarter           0.009861              0.010344
# document_create_date_dayofweek         0.004880              0.006895
# document_create_date_week              0.007549              0.008578
# baseline_create_date_month             0.007180              0.008852
# baseline_create_date_day               0.030722              0.026926
# baseline_create_date_year              0.009342              0.005059
# baseline_create_date_quarter           0.009123              0.010077
# baseline_create_date_dayofweek         0.007364              0.010011
# baseline_create_date_week              0.003602              0.005353
# document_create_is_working             0.006851              0.004966
# due_in_is_working                      0.000806              0.000738
# cust_delay_mean                             NaN              0.911004
# cust_name_delay_mean                        NaN                   NaN
# payment_time                                NaN                   NaN
# conv_amt                                    NaN                   NaN
#
#                                 payment_time  conv_amt
# buisness_year                            NaN       NaN
# doc_id                              0.097777  0.107574
# posting_id                               NaN       NaN
# area_business                            NaN       NaN
# total_open_amount                   0.085226  0.991581
# invoice_id                          0.097777  0.107574
# isOpen                                   NaN       NaN
# due_duration                        0.170181  0.007322
# code_business_code                  0.106154  0.054103
# code_cust_payment_terms             0.716410  0.129606
# code_cust_number                    0.077408  0.009493
# code_name_customer                  0.132034  0.074341
# posting_date_month                  0.007222  0.003869
# posting_date_day                    0.001107  0.021118
# posting_date_year                   0.013138  0.002871
# posting_date_quarter                0.015249  0.006719
# posting_date_dayofweek              0.010288  0.010952
# posting_date_week                   0.005321  0.000808
# due_in_date_month                   0.135214  0.010459
# due_in_date_day                     0.002553  0.017111
# due_in_date_year                    0.038297  0.004382
# due_in_date_quarter                 0.130257  0.009577
# due_in_date_dayofweek               0.013437  0.002089
# due_in_date_week                    0.134422  0.012486
# document_create_date_month          0.007222  0.003869
# document_create_date_day            0.001107  0.021118
# document_create_date_year           0.013138  0.002871
# document_create_date_quarter        0.015249  0.006719
# document_create_date_dayofweek      0.010288  0.010952
# document_create_date_week           0.005321  0.000808
# baseline_create_date_month          0.006627  0.002910
# baseline_create_date_day            0.013973  0.038752
# baseline_create_date_year           0.012289  0.002523
# baseline_create_date_quarter        0.014390  0.005101
# baseline_create_date_dayofweek      0.020083  0.023328
# baseline_create_date_week           0.003025  0.002432
# document_create_is_working          0.017880  0.008064
# due_in_is_working                   0.029221  0.014824
# cust_delay_mean                     0.050720  0.003477
# cust_name_delay_mean                0.070081  0.000386
# payment_time                             NaN  0.081212
# conv_amt                                 NaN       NaN
#
# [42 rows x 42 columns]

# %%
print([column for column in u.columns if any(u[column] ==1)])
# Out:
# ['invoice_id', 'document_create_date_month', 'document_create_date_day', 'document_create_date_year', 'document_create_date_quarter', 'document_create_date_dayofweek', 'document_create_date_week']

# %%
drop.append('invoice_id')

# %%
for i in df.columns:
    print(i)
    print(df[i].nunique())
    if df[i].nunique()<6:
        print(df[i].value_counts())
    print()
# Out:
# business_code
# 6
#
# cust_number
# 1301
#
# name_customer
# 3684
#
# buisness_year
# 1
# 2019    32073
# Name: buisness_year, dtype: int64
#
# doc_id
# 32073
#
# posting_date
# 283
#
# document_create_date
# 283
#
# due_in_date
# 342
#
# invoice_currency
# 2
# USD    29525
# CAD     2548
# Name: invoice_currency, dtype: int64
#
# document type
# 1
# RV    32073
# Name: document type, dtype: int64
#
# posting_id
# 1
# 1.0    32073
# Name: posting_id, dtype: int64
#
# area_business
# 0
# Series([], Name: area_business, dtype: int64)
#
# total_open_amount
# 29191
#
# baseline_create_date
# 290
#
# cust_payment_terms
# 65
#
# invoice_id
# 32073
#
# isOpen
# 1
# 0    32073
# Name: isOpen, dtype: int64
#
# due_duration
# 175
#
# code_business_code
# 6
#
# code_cust_payment_terms
# 65
#
# code_cust_number
# 1301
#
# code_name_customer
# 3684
#
# posting_date_month
# 11
#
# posting_date_day
# 31
#
# posting_date_year
# 2
# 2019    31938
# 2018      135
# Name: posting_date_year, dtype: int64
#
# posting_date_quarter
# 4
# 2    10903
# 3    10370
# 1     9875
# 4      925
# Name: posting_date_quarter, dtype: int64
#
# posting_date_dayofweek
# 7
#
# posting_date_week
# 42
#
# due_in_date_month
# 12
#
# due_in_date_day
# 31
#
# due_in_date_year
# 3
# 2019    32069
# 2018        3
# 2020        1
# Name: due_in_date_year, dtype: int64
#
# due_in_date_quarter
# 4
# 2    11093
# 3    10271
# 1     7820
# 4     2889
# Name: due_in_date_quarter, dtype: int64
#
# due_in_date_dayofweek
# 7
#
# due_in_date_week
# 52
#
# document_create_date_month
# 11
#
# document_create_date_day
# 31
#
# document_create_date_year
# 2
# 2019    31938
# 2018      135
# Name: document_create_date_year, dtype: int64
#
# document_create_date_quarter
# 4
# 2    10903
# 3    10370
# 1     9875
# 4      925
# Name: document_create_date_quarter, dtype: int64
#
# document_create_date_dayofweek
# 7
#
# document_create_date_week
# 42
#
# baseline_create_date_month
# 11
#
# baseline_create_date_day
# 31
#
# baseline_create_date_year
# 2
# 2019    31944
# 2018      129
# Name: baseline_create_date_year, dtype: int64
#
# baseline_create_date_quarter
# 4
# 2    10908
# 3    10359
# 1     9845
# 4      961
# Name: baseline_create_date_quarter, dtype: int64
#
# baseline_create_date_dayofweek
# 7
#
# baseline_create_date_week
# 43
#
# document_create_is_working
# 2
# 1    26529
# 0     5544
# Name: document_create_is_working, dtype: int64
#
# due_in_is_working
# 2
# 1    23118
# 0     8955
# Name: due_in_is_working, dtype: int64
#
# cust_delay_mean
# 513
#
# cust_name_delay_mean
# 813
#
# payment_time
# 52
#
# conv_amt
# 29202

# %%
drop.append('invoice_currency')
drop.append('document type')

# %%
import pickle
with open("drop", 'wb') as f:
    pickle.dump(drop, f)

# %%
df
# Out:
#       business_code cust_number       name_customer  buisness_year  \
# 1              U001  0200752302  KROGER corporation           2019
# 2              CA02  0140106408           WAL-M llc           2019
# 3              U001  0200744019           TARG corp           2019
# 4              U001  0200769623          WAL-MAR in           2019
# 5              U001  0200769623        WAL-MAR corp           2019
# ...             ...         ...                 ...            ...
# 32182          U001  0200799367     MCL corporation           2019
# 32183          U001  0200712105             WALG us           2019
# 32184          U001  0100031704      DELHAIZE trust           2019
# 32185          U001  0200705742      DOT foundation           2019
# 32186          U001  0200759878          SA systems           2019
#
#              doc_id posting_date document_create_date due_in_date  \
# 1      1.928537e+09   2018-12-30           2018-12-30  2019-01-14
# 2      2.960520e+09   2018-12-30           2018-12-30  2019-01-09
# 3      1.928532e+09   2018-12-30           2018-12-30  2019-01-14
# 4      1.928539e+09   2018-12-30           2018-12-30  2019-01-14
# 5      1.928543e+09   2018-12-30           2018-12-30  2019-01-14
# ...             ...          ...                  ...         ...
# 32182  1.929988e+09   2019-10-08           2019-10-08  2019-10-23
# 32183  1.929985e+09   2019-10-08           2019-10-08  2019-10-23
# 32184  1.929984e+09   2019-10-08           2019-10-08  2019-10-23
# 32185  1.929981e+09   2019-10-08           2019-10-08  2019-10-23
# 32186  1.929983e+09   2019-10-08           2019-10-08  2019-10-23
#
#       invoice_currency document type  ...  baseline_create_date_year  \
# 1                  USD            RV  ...                       2018
# 2                  CAD            RV  ...                       2018
# 3                  USD            RV  ...                       2018
# 4                  USD            RV  ...                       2018
# 5                  USD            RV  ...                       2018
# ...                ...           ...  ...                        ...
# 32182              USD            RV  ...                       2019
# 32183              USD            RV  ...                       2019
# 32184              USD            RV  ...                       2019
# 32185              USD            RV  ...                       2019
# 32186              USD            RV  ...                       2019
#
#        baseline_create_date_quarter  baseline_create_date_dayofweek  \
# 1                                 4                               6
# 2                                 4                               6
# 3                                 4                               6
# 4                                 4                               6
# 5                                 4                               6
# ...                             ...                             ...
# 32182                             4                               1
# 32183                             4                               1
# 32184                             4                               1
# 32185                             4                               1
# 32186                             4                               1
#
#       baseline_create_date_week document_create_is_working  due_in_is_working  \
# 1                            52                          0                  1
# 2                            52                          0                  1
# 3                            52                          0                  1
# 4                            52                          0                  1
# 5                            52                          0                  1
# ...                         ...                        ...                ...
# 32182                        41                          1                  1
# 32183                        41                          1                  1
# 32184                        41                          1                  1
# 32185                        41                          1                  1
# 32186                        41                          1                  1
#
#        cust_delay_mean  cust_name_delay_mean  payment_time    conv_amt
# 1             0.532710              1.145455            15  48419.6700
# 2             9.449848             10.702703            10  46353.7854
# 3             3.092282              2.433333            15  11309.1900
# 4            -2.138366             -2.528551            15   1248.1200
# 5            -2.138366             -2.180577            15   1763.9600
# ...                ...                   ...           ...         ...
# 32182         2.795556              1.576923            15  39618.6400
# 32183         7.521739              2.125000            15  62332.7000
# 32184         1.385455              3.312500            15  19033.4000
# 32185        -6.265421             -6.571429            15   8018.5800
# 32186         1.156553              0.556701            15  12753.7400
#
# [32073 rows x 52 columns]

# %%
df=df.drop(drop,axis=1)

# %%
def iqr(data):
    Q1 = np.percentile(data, 25, interpolation = 'midpoint')  
    Q2 = np.percentile(data, 50, interpolation = 'midpoint')  
    Q3 = np.percentile(data, 75, interpolation = 'midpoint')  
    IQR = Q3 - Q1  
    low_lim = Q1 - 1.5 * IQR 
    up_lim = Q3 + 1.5 * IQR 
    outlier=[]
    for x in data:
        if ((x> up_lim) or (x<low_lim)): 
             outlier.append(x) 
    print('outlier in the dataset is', len(outlier)) 
    return low_lim,up_lim

# %%
for i in df.columns:
    print(i)
    iqr(df[i])
# Out:
# buisness_year
# outlier in the dataset is 0
# doc_id
# outlier in the dataset is 3147
# total_open_amount
# outlier in the dataset is 1744
# due_duration
# outlier in the dataset is 2579
# code_business_code
# outlier in the dataset is 3155
# code_cust_payment_terms
# outlier in the dataset is 4654
# code_cust_number
# outlier in the dataset is 4213
# code_name_customer
# outlier in the dataset is 2568
# posting_date_month
# outlier in the dataset is 0
# posting_date_day
# outlier in the dataset is 0
# posting_date_year
# outlier in the dataset is 135
# posting_date_quarter
# outlier in the dataset is 0
# posting_date_dayofweek
# outlier in the dataset is 0
# posting_date_week
# outlier in the dataset is 0
# due_in_date_month
# outlier in the dataset is 0
# due_in_date_day
# outlier in the dataset is 0
# due_in_date_year
# outlier in the dataset is 4
# due_in_date_quarter
# outlier in the dataset is 0
# due_in_date_dayofweek
# outlier in the dataset is 0
# due_in_date_week
# outlier in the dataset is 0
# document_create_date_month
# outlier in the dataset is 0
# document_create_date_day
# outlier in the dataset is 0
# document_create_date_year
# outlier in the dataset is 135
# document_create_date_quarter
# outlier in the dataset is 0
# document_create_date_dayofweek
# outlier in the dataset is 0
# document_create_date_week
# outlier in the dataset is 0
# baseline_create_date_month
# outlier in the dataset is 0
# baseline_create_date_day
# outlier in the dataset is 0
# baseline_create_date_year
# outlier in the dataset is 129
# baseline_create_date_quarter
# outlier in the dataset is 0
# baseline_create_date_dayofweek
# outlier in the dataset is 0
# baseline_create_date_week
# outlier in the dataset is 0
# document_create_is_working
# outlier in the dataset is 5544
# due_in_is_working
# outlier in the dataset is 0
# cust_delay_mean
# outlier in the dataset is 2478
# cust_name_delay_mean
# outlier in the dataset is 2880
# payment_time
# outlier in the dataset is 8501
# conv_amt
# outlier in the dataset is 1685

# %%
modes = {}
for i in df.columns:
    modes[i]=df[i].mode()

# %%
Xtr=df.copy()

# %%
q=x_val.copy()

# %%
df=q
df['cust_delay_mean']=df['cust_number'].map(mapper1)
df['cust_name_delay_mean']=df['name_customer'].map(mapper2)
df['payment_time']=(df['due_in_date']-df['document_create_date']).dt.days
encoding(df)
dates_feature(df)
df['document_create_is_working']=np.where(df.document_create_date_dayofweek.isin([5,6]),0,1)
df['due_in_is_working']=np.where(df.due_in_date_dayofweek.isin([5,6]),0,1)
df['conv_amt']=df['total_open_amount'].copy()
df.loc[df['invoice_currency']=='CAD','conv_amt']=df.loc[df['invoice_currency']=='CAD','conv_amt']*0.78
df=df.drop(drop,axis=1)
df.columns.value_counts().sum()
# Out:
# 38

# %%
for i in df.columns:
    if df[i].isna().any():
        df[i].fillna(int(modes[i]),inplace=True)

for i in df.columns:
    if df[i].isna().any():
        print(i)

# %%
Xval=df.copy()

# %%
Xtr_bkp=Xtr.copy()
Xval_bkp=Xval.copy()

# %%
Xtr=Xtr_bkp.copy()
Xval=Xval_bkp.copy()

Ytr= Xtr['due_duration'].copy()
Xtr.drop(['due_duration'],axis=1,inplace=True)

Yval= Xval['due_duration'].copy()
Xval.drop(['due_duration'],axis=1,inplace=True)

# %%
list(zip(list(Xtr.columns),[1]*len(list(Xtr.columns))))
# Out:
# [('buisness_year', 1),
#  ('doc_id', 1),
#  ('total_open_amount', 1),
#  ('code_business_code', 1),
#  ('code_cust_payment_terms', 1),
#  ('code_cust_number', 1),
#  ('code_name_customer', 1),
#  ('posting_date_month', 1),
#  ('posting_date_day', 1),
#  ('posting_date_year', 1),
#  ('posting_date_quarter', 1),
#  ('posting_date_dayofweek', 1),
#  ('posting_date_week', 1),
#  ('due_in_date_month', 1),
#  ('due_in_date_day', 1),
#  ('due_in_date_year', 1),
#  ('due_in_date_quarter', 1),
#  ('due_in_date_dayofweek', 1),
#  ('due_in_date_week', 1),
#  ('document_create_date_month', 1),
#  ('document_create_date_day', 1),
#  ('document_create_date_year', 1),
#  ('document_create_date_quarter', 1),
#  ('document_create_date_dayofweek', 1),
#  ('document_create_date_week', 1),
#  ('baseline_create_date_month', 1),
#  ('baseline_create_date_day', 1),
#  ('baseline_create_date_year', 1),
#  ('baseline_create_date_quarter', 1),
#  ('baseline_create_date_dayofweek', 1),
#  ('baseline_create_date_week', 1),
#  ('document_create_is_working', 1),
#  ('due_in_is_working', 1),
#  ('cust_delay_mean', 1),
#  ('cust_name_delay_mean', 1),
#  ('payment_time', 1),
#  ('conv_amt', 1)]

# %%
feature_selection=[      ('buisness_year', 1),
                         ('doc_id', 1),
                         ('total_open_amount', 1),
                         ('code_business_code', 1),
                         ('code_cust_payment_terms', 1),
                         ('code_cust_number', 1),
                         ('code_name_customer', 1),
                         ('posting_date_month', 1),
                         ('posting_date_day', 1),
                         ('posting_date_year', 1),
                         ('posting_date_quarter', 1),
                         ('posting_date_dayofweek', 1),
                         ('posting_date_week', 1),
                         ('due_in_date_month', 1),
                         ('due_in_date_day', 1),
                         ('due_in_date_year', 1),
                         ('due_in_date_quarter', 1),
                         ('due_in_date_dayofweek', 1),
                         ('due_in_date_week', 1),
                         ('document_create_date_month', 1),
                         ('document_create_date_day', 1),
                         ('document_create_date_year', 1),
                         ('document_create_date_quarter', 1),
                         ('document_create_date_dayofweek', 1),
                         ('document_create_date_week', 1),
                         ('baseline_create_date_month', 1),
                         ('baseline_create_date_day', 1),
                         ('baseline_create_date_year', 1),
                         ('baseline_create_date_quarter', 1),
                         ('baseline_create_date_dayofweek', 1),
                         ('baseline_create_date_week', 1),
                         ('document_create_is_working', 1),
                         ('due_in_is_working', 1),
                         ('cust_delay_mean', 1),
                         ('cust_name_delay_mean', 1),
                         ('payment_time', 1)]

# %%
feature=[]
for i in feature_selection:
    if i[1]==1:
        feature.append(i[0])

# %%
Xtr=Xtr[feature].copy()
Xval=Xval[feature].copy()

# %% [markdown]
# ## Which model to select

# %%
# Defining Lists to Store in the Results and Names of Algorithms
MSE_Score = []
R2_Score = []
Algorithm = []

# %% [markdown]
# ### **1. Linear Regression**

# %%
# Fitting Simple Linear Regression to the Training Set
Algorithm.append('Linear Regression')
clf = LinearRegression()
clf.fit(Xtr, Ytr)

# Predicting the Test Set Results
predicted = clf.predict(Xval)

# %%
# Appending the Scores For Visualisation at a Later Part
MSE_Score.append(mean_squared_error(Yval, predicted))
R2_Score.append(r2_score(Yval, predicted))

# %% [markdown]
# ### **2. Support Vector Regression**

# %%
# Fitting SVR to the Training Set
Algorithm.append('Support Vector Regression')
clf = SVR()
clf.fit(Xtr, Ytr)

# Predicting the Test Set Results
predicted = clf.predict(Xval)

# %%
# Appending the Scores For Visualisation at a Later Part
MSE_Score.append(mean_squared_error(Yval, predicted))
R2_Score.append(r2_score(Yval, predicted))

# %% [markdown]
# ### **3. Decision Tree Regressor**

# %%
# Fitting Decision Tree to the Training Set
Algorithm.append('Decision Tree Regressor')
clf = DecisionTreeRegressor()
clf.fit(Xtr, Ytr)

# Predicting the Test Set Results
predicted = clf.predict(Xval)

# %%
# Appending the Scores For Visualisation at a Later Part
MSE_Score.append(mean_squared_error(Yval, predicted))
R2_Score.append(r2_score(Yval, predicted))

# %% [markdown]
# ### **4. Random Forest Regressor**

# %%
# Fitting Random Forest Regressor Tree to the Training Set
Algorithm.append('Random Forest Regressor')
clf = RandomForestRegressor()
clf.fit(Xtr, Ytr)

# Predicting the Test Set Results
predicted = clf.predict(Xval)

# %%
# Appending the Scores For Visualisation at a Later Part
MSE_Score.append(mean_squared_error(Yval, predicted))
R2_Score.append(r2_score(Yval, predicted))

# %% [markdown]
# ### **5. XGB Regressor**

# %%
# Fitting XGBoost Regressor to the Training Set
Algorithm.append('XGB Regressor')
clf = xgb.XGBRegressor(objective ='reg:squarederror')
clf.fit(Xtr, Ytr)

# Predicting the Test Set Results
predicted = clf.predict(Xval)

# %%
# Appending the Scores For Visualisation at a Later Part
MSE_Score.append(mean_squared_error(Yval, predicted))
R2_Score.append(r2_score(Yval, predicted))

# %% [markdown]
# ## Score Card of the Models' Performances

# %%
# Just Combining the Lists into a DataFrame for a Better Visualisation
Comparison = pd.DataFrame(list(zip(Algorithm, MSE_Score, R2_Score)), columns = ['Algorithm', 'MSE_Score', 'R2_Score'])

# %%
# Score Card  # Accuracies are bad due to low time
Comparison
# Out:
#                    Algorithm   MSE_Score  R2_Score
# 0          Linear Regression   52.475807 -0.050440
# 1  Support Vector Regression   48.959723  0.019944
# 2    Decision Tree Regressor  127.164266 -1.545523
# 3    Random Forest Regressor   45.472117  0.089757
# 4              XGB Regressor   62.139608 -0.243886

# %% [markdown]
# Selecting the model

# %% [markdown]
# ## Random Forest

# %%
MSE_Score = []
R2_Score = []
Algorithm = []
MAE_Score = []
RMSE_Score = []
isTrue = []
isFalse = []
AllFeatures = []

# %%
Xtr=Xtr_bkp.copy()
Xval=Xval_bkp.copy()

# %%
Ytr= Xtr['due_duration'].copy()
Xtr.drop(['due_duration'],axis=1,inplace=True)

# %%
Yval= Xval['due_duration'].copy()
Xval.drop(['due_duration'],axis=1,inplace=True)

# %%
list(zip(list(Xtr.columns),[1]*len(list(Xtr.columns))))
# Out:
# [('buisness_year', 1),
#  ('doc_id', 1),
#  ('total_open_amount', 1),
#  ('code_business_code', 1),
#  ('code_cust_payment_terms', 1),
#  ('code_cust_number', 1),
#  ('code_name_customer', 1),
#  ('posting_date_month', 1),
#  ('posting_date_day', 1),
#  ('posting_date_year', 1),
#  ('posting_date_quarter', 1),
#  ('posting_date_dayofweek', 1),
#  ('posting_date_week', 1),
#  ('due_in_date_month', 1),
#  ('due_in_date_day', 1),
#  ('due_in_date_year', 1),
#  ('due_in_date_quarter', 1),
#  ('due_in_date_dayofweek', 1),
#  ('due_in_date_week', 1),
#  ('document_create_date_month', 1),
#  ('document_create_date_day', 1),
#  ('document_create_date_year', 1),
#  ('document_create_date_quarter', 1),
#  ('document_create_date_dayofweek', 1),
#  ('document_create_date_week', 1),
#  ('baseline_create_date_month', 1),
#  ('baseline_create_date_day', 1),
#  ('baseline_create_date_year', 1),
#  ('baseline_create_date_quarter', 1),
#  ('baseline_create_date_dayofweek', 1),
#  ('baseline_create_date_week', 1),
#  ('document_create_is_working', 1),
#  ('due_in_is_working', 1),
#  ('cust_delay_mean', 1),
#  ('cust_name_delay_mean', 1),
#  ('payment_time', 1),
#  ('conv_amt', 1)]

# %%
feature_selection=[      ('buisness_year', 0),
                         ('doc_id', 0),
                         ('document type', 0),
                         ('posting_id', 0),
                         ('total_open_amount', 0),
                         ('invoice_id', 0),
                         ('conv_amt', 1),
                         ('cust_delay_mean', 1),
                         ('cust_name_delay_mean', 0),
                         ('payment_time', 1),
                         ('code_business_code', 0),
                         ('code_cust_payment_terms', 1),
                         ('code_cust_number', 1),
                         ('code_name_customer', 0),
                         ('posting_date_month', 1),
                         ('posting_date_day', 1),
                         ('posting_date_year', 0),
                         ('posting_date_quarter', 0),
                         ('posting_date_dayofweek', 0),
                         ('posting_date_week', 0),
                         ('due_in_date_month', 1),
                         ('due_in_date_day', 1),
                         ('due_in_date_year', 0),
                         ('due_in_date_quarter', 1),
                         ('due_in_date_dayofweek', 1),
                         ('due_in_date_week', 0),
                         ('document_create_date_month', 1),
                         ('document_create_date_day', 1),
                         ('document_create_date_year', 0),
                         ('document_create_date_quarter', 1),
                         ('document_create_date_dayofweek', 1),
                         ('document_create_date_week', 0),
                         ('baseline_create_date_month', 1),
                         ('baseline_create_date_day', 1),
                         ('baseline_create_date_year', 0),
                         ('baseline_create_date_quarter', 0),
                         ('baseline_create_date_dayofweek', 0),
                         ('baseline_create_date_week', 0),
                         ('document_create_is_working', 1),
                         ('due_in_is_working', 1)]

# %%
feature=[]
for i in feature_selection:
    if i[1]==1:
        feature.append(i[0])

# %%
AllFeatures.append(feature)

# %%
Xtr=Xtr[feature].copy()
Xval=Xval[feature].copy()

# %%
def stan(a,n):
    if n==1:
        scaler = StandardScaler()
    elif n==2:
        scaler = preprocessing.QuantileTransformer(output_distribution='normal', random_state=0)
    return scaler

# %%
df=Xtr
scaler=stan(df,1)
scaler.fit(df)
Xtr=scaler.transform(df)
df=Xval
scaler=stan(df,1)
scaler.fit(df)
Xval=scaler.transform(df)

# %%
valS=[]
TrS=[]
n_e=[]
m_d=[]
m_s=[]
m_l=[]

# %%
n_e.append(45)
m_d.append(55)
m_s.append(25)
m_l.append(15)

# %%
clf = RandomForestRegressor(n_estimators=n_e[-1],max_depth=m_d[-1],min_samples_leaf=m_s[-1],min_samples_split=m_l[-1])
qwerty=clf.fit(Xtr, Ytr)

# %%
print(qwerty.score(Xval, Yval))
valS.append(qwerty.score(Xval, Yval))
TrS.append(qwerty.score(Xtr, Ytr))
qwerty.score(Xtr, Ytr)
# Out:
# -0.11686187253787583
# 0.6178023980352823

# %%
pd.DataFrame(list(zip(valS,TrS,n_e,m_d,m_s,m_l)))
# Out:
#           0         1   2   3   4   5
# 0 -0.116862  0.617802  45  55  25  15

# %%
predicted1 = clf.predict(Xtr)
predicted = clf.predict(Xval)
MSE_Score.append(mean_squared_error(Yval, predicted))
R2_Score.append(r2_score(Yval, predicted))
MAE_Score.append(mean_absolute_error(Yval, predicted))
RMSE_Score.append(np.sqrt(mean_squared_error(Yval, predicted)))
A=((abs((pd.Series(np.around(predicted)).astype(int)-Yval.reset_index(drop=True))))<4).value_counts().to_frame().T
for i in A.columns:
    if i==True:
        isTrue.append(int(A[i]))
    else:
        isFalse.append(int(A[i]))

# %%
# Just Combining the Lists into a DataFrame for a Better Visualisation
Comparison = pd.DataFrame(list(zip(MSE_Score,RMSE_Score, R2_Score,MAE_Score,isTrue,isFalse,AllFeatures,valS,TrS,n_e,m_d,m_s,m_l)), columns = ['MSE_Score','RMSE_Score', 'R2_Score','MAE_Score','isTrue','isFalse','Allfeatures','valS','TrS','n_e','m_d','m_s','m_l'])

# %%
# Score Card
Comparison[['MSE_Score','RMSE_Score', 'R2_Score','MAE_Score','isTrue','isFalse']]
# Out:
#    MSE_Score  RMSE_Score  R2_Score  MAE_Score  isTrue  isFalse
# 0  57.024909    7.551484 -0.141502   4.616333    3737     3136

# %% [markdown]
# ## Test Set

# %%
Xte=x_test.copy()

# %%
x_test
# Out:
#       business_code cust_number        name_customer  buisness_year  \
# 39061          U001  0200772670         ASSOCIAT llc           2019
# 39062          U001  0200712187           SPAR trust           2019
# 39063          U001  0100031704  DELHAIZE foundation           2019
# 39064          U001  0200769623          WAL-MAR llc           2019
# 39065          U001  0200762301            C&S WH in           2019
# ...             ...         ...                  ...            ...
# 45952          CA02  0140106408             WAL-M co           2020
# 45953          U001  0200865666           RESTAU llc           2020
# 45954          U001  0200326954              NEWE in           2020
# 45955          U001  0200772595               SAFEW            2020
# 45956          CA02  0140105686             SYSC llc           2020
#
#              doc_id posting_date document_create_date due_in_date  \
# 39061  1.930252e+09   2019-12-09           2019-12-09  2019-12-24
# 39062  1.930254e+09   2019-12-09           2019-12-09  2019-12-24
# 39063  1.930230e+09   2019-12-09           2019-12-09  2019-12-24
# 39064  1.930257e+09   2019-12-09           2019-12-09  2019-12-24
# 39065  1.930249e+09   2019-12-09           2019-12-09  2019-12-24
# ...             ...          ...                  ...         ...
# 45952  2.960617e+09   2020-02-26           2020-02-26  2020-03-08
# 45953  1.930577e+09   2020-02-26           2020-02-26  2020-03-12
# 45954  1.930574e+09   2020-02-26           2020-02-26  2020-03-04
# 45955  1.930574e+09   2020-02-26           2020-02-26  2020-03-12
# 45956  2.960616e+09   2020-02-26           2020-02-26  2020-03-15
#
#       invoice_currency document type  posting_id  area_business  \
# 39061              USD            RV         1.0            NaN
# 39062              USD            RV         1.0            NaN
# 39063              USD            RV         1.0            NaN
# 39064              USD            RV         1.0            NaN
# 39065              USD            RV         1.0            NaN
# ...                ...           ...         ...            ...
# 45952              CAD            RV         1.0            NaN
# 45953              USD            RV         1.0            NaN
# 45954              USD            RV         1.0            NaN
# 45955              USD            RV         1.0            NaN
# 45956              CAD            RV         1.0            NaN
#
#        total_open_amount baseline_create_date cust_payment_terms  \
# 39061           13617.04           2019-12-09               NAU5
# 39062          137722.95           2019-12-09               NAA8
# 39063           44164.82           2019-12-09               NAA8
# 39064            2237.43           2019-12-09               NAH4
# 39065           26435.11           2019-12-09               NAC6
# ...                  ...                  ...                ...
# 45952           44479.13           2020-02-27               CA10
# 45953            4304.37           2020-02-26               NAA8
# 45954           73652.23           2020-02-26               NAD8
# 45955           50210.26           2020-02-26               NAA8
# 45956            3336.00           2020-03-05               CA10
#
#          invoice_id  isOpen  due_duration
# 39061  1.930252e+09       0             2
# 39062  1.930254e+09       0            -1
# 39063  1.930230e+09       0             3
# 39064  1.930257e+09       0            -4
# 39065  1.930249e+09       0             0
# ...             ...     ...           ...
# 45952  2.960617e+09       0             5
# 45953  1.930577e+09       0             0
# 45954  1.930574e+09       0             2
# 45955  1.930574e+09       0             0
# 45956  2.960616e+09       0             4
#
# [6873 rows x 18 columns]

# %%
df=Xte
df['cust_delay_mean']=df['cust_number'].map(mapper1)
df['cust_name_delay_mean']=df['name_customer'].map(mapper2)
df['payment_time']=(df['due_in_date']-df['document_create_date']).dt.days
encoding(df)
dates_feature(df)
df['document_create_is_working']=np.where(df.document_create_date_dayofweek.isin([5,6]),0,1)
df['due_in_is_working']=np.where(df.due_in_date_dayofweek.isin([5,6]),0,1)
df['conv_amt']=df['total_open_amount'].copy()

df.loc[df['invoice_currency']=='CAD','conv_amt']=df.loc[df['invoice_currency']=='CAD','conv_amt']*0.78
df=df.drop(drop,axis=1)
df.columns.value_counts().sum()
# Out:
# 38

# %%
for i in df.columns:
    if df[i].isna().any():
        df[i].fillna(int(modes[i]),inplace=True)

for i in df.columns:
    if df[i].isna().any():
        print(i)

# %%
Yte= Xte['due_duration'].copy()
Xte.drop(['due_duration'],axis=1,inplace=True)

# %%
Xte=df.copy()
Xte=Xte[feature].copy()

# %%
df=Xte
scaler=stan(df,1)
scaler.fit(df)
Xte=scaler.transform(df)

# %%
predicted1 = clf.predict(Xtr)
predicted = clf.predict(Xte)
print(mean_squared_error(Yval, predicted))
print(r2_score(Yval, predicted))
print(mean_absolute_error(Yval, predicted))
print(np.sqrt(mean_squared_error(Yval, predicted)))
A=((abs((pd.Series(np.around(predicted)).astype(int)-Yval.reset_index(drop=True))))<4).value_counts().to_frame().T
for i in A.columns:
    if i==True:
        print('True',int(A[i]))
    else:
        print('False',int(A[i]))
# Out:
# 54.2555385350819
# -0.08606570213391307
# 4.3901971148963685
# 7.365835901992516
# True 3897
# False 2976

# %% [markdown]
# ## Prediction on main data

# %%
df=data_null_cleardate.copy()

# %%
df=df.drop(['clear_date'],axis=1)

# %%
df['cust_delay_mean']=df['cust_number'].map(mapper1)
df['cust_name_delay_mean']=df['name_customer'].map(mapper2)
df['payment_time']=(df['due_in_date']-df['document_create_date']).dt.days
encoding(df)
dates_feature(df)
df['document_create_is_working']=np.where(df.document_create_date_dayofweek.isin([5,6]),0,1)
df['due_in_is_working']=np.where(df.due_in_date_dayofweek.isin([5,6]),0,1)
df['conv_amt']=df['total_open_amount'].copy()

df.loc[df['invoice_currency']=='CAD','conv_amt']=df.loc[df['invoice_currency']=='CAD','conv_amt']*0.78
df=df.drop(drop,axis=1)
df.columns.value_counts().sum()
# Out:
# 37

# %%
for i in df.columns:
    if df[i].isna().any():
        df[i].fillna(int(modes[i]),inplace=True)

for i in df.columns:
    if df[i].isna().any():
        print(i)

# %%
XM=df.copy()
XM=XM[feature].copy()

# %%
df=XM
scaler=stan(df,1)
scaler.fit(df)
XM=scaler.transform(df)

# %%
predicted = clf.predict(XM)

# %%
qwer=pd.DataFrame(np.around(predicted).astype(np.int64))

# %%
qwer[0]= qwer[0].astype(str) + ' day'

# %%
qwer
# Out:
#           0
# 0     1 day
# 1     1 day
# 2     1 day
# 3     1 day
# 4     1 day
# ...     ...
# 4036  1 day
# 4037  5 day
# 4038  1 day
# 4039  6 day
# 4040  0 day
#
# [4041 rows x 1 columns]

# %%
qwer=pd.to_timedelta(qwer[0])

# %%
Final_dates=data_null_cleardate['due_in_date'] + qwer[0]

# %%
Final_dates
# Out:
# 0      2020-03-14
# 1      2020-03-14
# 2      2020-03-14
# 3      2020-03-14
# 4      2020-03-14
#           ...
# 4036   2020-05-30
# 4037   2020-06-03
# 4038   2020-05-30
# 4039   2020-06-05
# 4040   2020-06-22
# Name: due_in_date, Length: 4041, dtype: datetime64[ns]
